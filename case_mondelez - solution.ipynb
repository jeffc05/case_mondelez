# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot
import seaborn as sns
import statsmodels.tsa.api as tsa
import sktime

# %%
df_invoice = pd.read_excel('Invoice.xlsx')
df_promo = pd.read_excel('Promo.xlsx')

# %%
df_invoice.head()
# Out:
#    INVOICE_CD  MATERIAL_NUM_CD SALESORG_CD  CUSTOMER_SOLD_TO_CD LOCATION_CD  \
# 0  3690102789           654006        HU01              6424997        HU93
# 1  3690103366          4028405        HU01              6424997        HU93
# 2  3690103735           654006        HU01              6424997        HU93
# 3  3690103735          4028405        HU01              6424997        HU93
# 4  3690104623          4028405        HU01              6424997        HU93
#
#    invoice_qty INVOICE_DT  week_num  month_num  qtr_num  \
# 0    14.697011 2017-02-20         8          2        1
# 1    10.884171 2017-03-06        10          3        1
# 2    14.882567 2017-03-16        11          3        1
# 3    10.299208 2017-03-16        11          3        1
# 4    10.299208 2017-03-22        12          3        1
#
#   CUSTOMER_HIERARCHY_LVL2_CD basecode   brand_cd category_cd
# 0                   HU000106   HU0261  EUCOCOBPA      EUCOCO
# ...

# %%
df_promo.head()
# Out:
#    promo_cd status_cd basecode location_cd customer_hierarchy_lvl2_cd  \
# 0     19279  Approved   HU0261        HU93                   HU000101
# 1     19280  Approved   HU0063        HU93                   HU000101
# 2     19281  Approved   HU0044        HU93                   HU000101
# 3     19282  Approved   HU0060        HU93                   HU000101
# 4     19283  Approved   HU0028        HU93                   HU000101
#
#   salesorg_cd ship_start_dt ship_end_dt event_end_dt event_start_dt  \
# 0        HU01    2017-03-03  2017-03-05   2017-03-05     2017-03-03
# 1        HU01    2017-03-01  2017-03-10   2017-03-10     2017-03-08
# 2        HU01    2017-04-13  2017-04-20   2017-04-20     2017-04-13
# 3        HU01    2017-04-07  2017-04-17   2017-04-17     2017-04-15
# 4        HU01    2017-05-18  2017-05-27   2017-05-27     2017-05-25
#
#   promo_mechanic_nm promo_mechanic_desc
# 0           Pricing                 TPR
# 1           Pricing                 TPR
# ...
